# %% [markdown]
# ## Introduction to BGP Analysis using Batfish

# %% [markdown]
# Network engineers routinely need to validate BGP configuration and session status in the network. They often do that by connecting to multiple network devices and executing a series of `show ip bgp` commands. This distributed debugging is highly complex even in a moderately-sized network. And it is reactive, the configuration changes are already in the network.
#
# Batfish allows network engineers to proactively validate BGP configuration to ensure sessions are compatibly configured and will be established, thereby avoiding potential network outages.
#
# In this notebook, we will look at how you can extract BGP configuration and session status information from Batfish.
#
# ![Analytics](https://ga-beacon.appspot.com/UA-100596389-3/open-source/pybatfish/jupyter_notebooks/intro-bgp-analysis?pixel&useReferer)

# %%
# Import packages and load questions
# %run startup.py

load_questions()

# %% [markdown]
# ### Initializing the Network and Snapshot

# %% [markdown]
# `SNAPSHOT_PATH` below can be updated to point to a custom snapshot directory, see the [Batfish instructions](https://github.com/batfish/batfish/wiki/Packaging-snapshots-for-analysis) for how to package data for analysis.<br>
# More example networks are available in the [networks](https://github.com/batfish/batfish/tree/master/networks) folder of the Batfish repository.

# %%
# Initialize a network and snapshot
NETWORK_NAME = "example_n"
SNAPSHOT_NAME = "example_s"

SNAPSHOT_PATH = "networks/basic/networks/fattree4"
# SNAPSHOT_PATH = "networks/example-bgp"

bf_set_network(NETWORK_NAME)
bf_init_snapshot(SNAPSHOT_PATH, name=SNAPSHOT_NAME, overwrite=True)
# Out:
# 'example_s'

# %%
# help(bf_upload_diagnostics)

# %% [markdown]
# All of the information we will show you in this notebook is dynamically computed by Batfish based on the configuration files for the network devices.

# %% [markdown]
# ### Batfish BGP related questions

# %% [markdown]
# Batfish has a number of questions dedicated to extracting BGP configuration and state information. This notebook will show you how to use each of them to extract information you need to validate a configuration change or troubleshoot a BGP issue

# %% [markdown]
# 1) `bfq.bgpProcessConfiguration` - This will return common information about the BGP process: router id, whether the device is acting as a route-reflector, multipath settings, list of neighbors, etc.
#
# 2) `bfq.bgpPeerConfiguration` - This will return the list of neighbors for the given node(s) and specific attributes for each configured neighbor such as: device local IP address, Local Interface (only use for BGP unnumbered sessions), remote-as, remote/peer/neighbor IP, peer-group, import and export policy, etc.
#
# 3) `bfq.bgpSessionCompatbility` - For each configured BGP peer, this question will return the `Configured_Status`. This is Batfish's view of whether or not a given BGP session is properly configured. Any peer that does not have `Configured_Status` equal to `UNIQUE_MATCH` or `DYNAMIC_MATCH` is misconfigured.
#
# 4) `bfq.bgpSessionStatus` - For each configured BGP peer, this question will return the `Established_Status`. This is the status of the session after Batfish has completed analyzing the configurations and building the routing and forwarding tables. Any BGP peer which has `Established_Status` other than `ESTABLISHED` indicates a misconfiguration.
#
# In addition to these 4 questions, we have created questions designed to test routing policies, which we will cover in a subsequent notebook.

# %% [markdown]
# ### View BGP Configuration for ALL devices
# Batfish makes BGP Configuration settings in the network easily accessible. Let's take a look at how you can retrieve the specific information you want. Let's start with configuration attributes of the BGP process on all devices running BGP by using the question `bfq.bgpProcessConfiguration`.

# %%
# Get BGP process configuration information for ALL devices
bgp_config = bfq.bgpProcessConfiguration().answer().frame()
bgp_config
# Out:
#              Node      VRF  Router_ID Confederation_ID Confederation_Members  \
# 0          edge-3  default   70.0.6.0             None                  None
# 1          edge-6  default  70.0.12.0             None                  None
# 2   aggregation-4  default  70.0.20.0             None                  None
# 3          core-0  default  70.0.24.0             None                  None
# 4          edge-7  default  70.0.14.0             None                  None
# 5   aggregation-1  default  70.0.17.0             None                  None
# 6   aggregation-2  default  70.0.18.0             None                  None
# 7   aggregation-6  default  70.0.22.0             None                  None
# 8          edge-0  default   70.0.0.0             None                  None
# 9   aggregation-5  default  70.0.21.0             None                  None
# 10  aggregation-3  default  70.0.19.0             None                  None
# 11         edge-5  default  70.0.10.0             None                  None
# 12         core-2  default  70.0.26.0             None                  None
# 13         edge-1  default   70.0.2.0             None                  None
# 14         edge-4  default   70.0.8.0             None                  None
# 15  aggregation-7  default  70.0.23.0             None                  None
# 16         core-3  default  70.0.27.0             None                  None
# 17  aggregation-0  default  70.0.16.0             None                  None
# 18         edge-2  default   70.0.4.0             None                  None
# 19         core-1  default  70.0.25.0             None                  None
#
#    Multipath_EBGP Multipath_IBGP Multipath_Match_Mode  \
# 0           False          False          PATH_LENGTH
# 1           False          False          PATH_LENGTH
# 2           False          False          PATH_LENGTH
# 3           False          False          PATH_LENGTH
# 4           False          False          PATH_LENGTH
# 5           False          False          PATH_LENGTH
# 6           False          False          PATH_LENGTH
# 7           False          False          PATH_LENGTH
# 8           False          False          PATH_LENGTH
# 9           False          False          PATH_LENGTH
# 10          False          False          PATH_LENGTH
# 11          False          False          PATH_LENGTH
# 12          False          False          PATH_LENGTH
# 13          False          False          PATH_LENGTH
# 14          False          False          PATH_LENGTH
# 15          False          False          PATH_LENGTH
# 16          False          False          PATH_LENGTH
# 17          False          False          PATH_LENGTH
# 18          False          False          PATH_LENGTH
# 19          False          False          PATH_LENGTH
#
#                                                        Neighbors  \
# 0                                 ['10.1.1.1/32', '10.1.1.3/32']
# 1                                 ['10.3.0.1/32', '10.3.0.3/32']
# 2   ['10.2.0.0/32', '10.2.1.0/32', '10.2.2.1/32', '10.2.2.3/32']
# 3   ['10.0.2.0/32', '10.1.2.0/32', '10.2.2.0/32', '10.3.2.0/32']
# 4                                 ['10.3.1.1/32', '10.3.1.3/32']
# 5   ['10.0.0.2/32', '10.0.1.2/32', '10.0.3.1/32', '10.0.3.3/32']
# 6   ['10.1.0.0/32', '10.1.1.0/32', '10.1.2.1/32', '10.1.2.3/32']
# 7   ['10.3.0.0/32', '10.3.1.0/32', '10.3.2.1/32', '10.3.2.3/32']
# 8                                 ['10.0.0.1/32', '10.0.0.3/32']
# 9   ['10.2.0.2/32', '10.2.1.2/32', '10.2.3.1/32', '10.2.3.3/32']
# 10  ['10.1.0.2/32', '10.1.1.2/32', '10.1.3.1/32', '10.1.3.3/32']
# 11                                ['10.2.1.1/32', '10.2.1.3/32']
# 12  ['10.0.3.0/32', '10.1.3.0/32', '10.2.3.0/32', '10.3.3.0/32']
# 13                                ['10.0.1.1/32', '10.0.1.3/32']
# 14                                ['10.2.0.1/32', '10.2.0.3/32']
# 15  ['10.3.0.2/32', '10.3.1.2/32', '10.3.3.1/32', '10.3.3.3/32']
# 16  ['10.0.3.2/32', '10.1.3.2/32', '10.2.3.2/32', '10.3.3.2/32']
# 17  ['10.0.0.0/32', '10.0.1.0/32', '10.0.2.1/32', '10.0.2.3/32']
# 18                                ['10.1.0.1/32', '10.1.0.3/32']
# 19  ['10.0.2.2/32', '10.1.2.2/32', '10.2.2.2/32', '10.3.2.2/32']
#
#    Route_Reflector    Tie_Breaker
# 0            False  ARRIVAL_ORDER
# 1            False  ARRIVAL_ORDER
# 2            False  ARRIVAL_ORDER
# 3            False  ARRIVAL_ORDER
# 4            False  ARRIVAL_ORDER
# 5            False  ARRIVAL_ORDER
# 6            False  ARRIVAL_ORDER
# 7            False  ARRIVAL_ORDER
# 8            False  ARRIVAL_ORDER
# 9            False  ARRIVAL_ORDER
# 10           False  ARRIVAL_ORDER
# 11           False  ARRIVAL_ORDER
# 12           False  ARRIVAL_ORDER
# 13           False  ARRIVAL_ORDER
# 14           False  ARRIVAL_ORDER
# 15           False  ARRIVAL_ORDER
# 16           False  ARRIVAL_ORDER
# 17           False  ARRIVAL_ORDER
# 18           False  ARRIVAL_ORDER
# 19           False  ARRIVAL_ORDER

# %% [markdown]
# Now let's drill into the configuration of a specific BGP session. Let's look at the sessions on `as2dept1`. To do this, we will use the `bfq.bgpPeerConfiguration` question.

# %%
# Get all of the BGP peer configuration for as2dept1 devices
bgp_peer_config = bfq.bgpPeerConfiguration().answer().frame()
bgp_peer_config
# Out:
#              Node      VRF Local_AS  Local_IP Local_Interface Confederation  \
# 0          core-2  default       13  10.3.3.1            None          None
# 1   aggregation-1  default        9  10.0.3.0            None          None
# 2   aggregation-5  default       11  10.2.1.3            None          None
# 3          edge-1  default        2  10.0.1.2            None          None
# 4   aggregation-5  default       11  10.2.3.2            None          None
# ..            ...      ...      ...       ...             ...           ...
# 59         core-3  default       13  10.0.3.3            None          None
# 60         core-2  default       13  10.0.3.1            None          None
# 61  aggregation-0  default        9  10.0.1.1            None          None
# 62         edge-4  default        5  10.2.0.2            None          None
# 63  aggregation-0  default        9  10.0.0.1            None          None
#
#    Remote_AS Remote_IP Description Route_Reflector_Client Cluster_ID  \
# 0         12  10.3.3.0        None                  False       None
# 1         13  10.0.3.1        None                  False       None
# 2          6  10.2.1.2        None                  False       None
# 3          9  10.0.1.3        None                  False       None
# 4         13  10.2.3.3        None                  False       None
# ..       ...       ...         ...                    ...        ...
# 59         9  10.0.3.2        None                  False       None
# 60         9  10.0.3.0        None                  False       None
# 61         2  10.0.1.0        None                  False       None
# 62        11  10.2.0.3        None                  False       None
# 63         1  10.0.0.0        None                  False       None
#
#    Peer_Group Import_Policy Export_Policy Send_Community Is_Passive
# 0        None            []            []           True      False
# 1        None            []            []           True      False
# 2        None            []            []           True      False
# 3        None            []            []           True      False
# 4        None            []            []           True      False
# ..        ...           ...           ...            ...        ...
# 59       None            []            []           True      False
# 60       None            []            []           True      False
# 61       None            []            []           True      False
# 62       None            []            []           True      False
# 63       None            []            []           True      False
#
# [64 rows x 16 columns]

# %% [markdown]
# ### View BGP Session Status

# %% [markdown]
# Now that we have seen the configuration for each peer on `as2dept1`, let's ensure that their configuration is compatible with their peers
#
# The `bgpSessionCompatibility` question allows you to ensure that BGP sessions are compatibly configured, so that if there is IP reachability between the peers the sessions will be established. Compatiblity checks that the remote-as matches up on both ends, the correct update source is specified, peer-ip addresses match-up, etc...

# %%
# Check if the bgp Sessions on as2dept1 are properly configured
bgpSessCompat = bfq.bgpSessionCompatibility().answer().frame()
bgpSessCompat
# Out:
#              Node      VRF Local_AS Local_Interface  Local_IP Remote_AS  \
# 0   aggregation-0  default        9            None  10.0.0.1         1
# 1   aggregation-0  default        9            None  10.0.1.1         2
# 2   aggregation-0  default        9            None  10.0.2.0        13
# 3   aggregation-0  default        9            None  10.0.2.2        13
# 4   aggregation-1  default        9            None  10.0.0.3         1
# ..            ...      ...      ...             ...       ...       ...
# 59         edge-5  default        6            None  10.2.1.2        11
# 60         edge-6  default        7            None  10.3.0.0        12
# 61         edge-6  default        7            None  10.3.0.2        12
# 62         edge-7  default        8            None  10.3.1.0        12
# 63         edge-7  default        8            None  10.3.1.2        12
#
#       Remote_Node Remote_Interface Remote_IP  Address_Families  \
# 0          edge-0             None  10.0.0.0  ['IPV4_UNICAST']
# 1          edge-1             None  10.0.1.0  ['IPV4_UNICAST']
# 2          core-0             None  10.0.2.1  ['IPV4_UNICAST']
# 3          core-1             None  10.0.2.3  ['IPV4_UNICAST']
# 4          edge-0             None  10.0.0.2  ['IPV4_UNICAST']
# ..            ...              ...       ...               ...
# 59  aggregation-5             None  10.2.1.3  ['IPV4_UNICAST']
# 60  aggregation-6             None  10.3.0.1  ['IPV4_UNICAST']
# 61  aggregation-7             None  10.3.0.3  ['IPV4_UNICAST']
# 62  aggregation-6             None  10.3.1.1  ['IPV4_UNICAST']
# 63  aggregation-7             None  10.3.1.3  ['IPV4_UNICAST']
#
#       Session_Type Configured_Status
# 0   EBGP_SINGLEHOP      UNIQUE_MATCH
# 1   EBGP_SINGLEHOP      UNIQUE_MATCH
# 2   EBGP_SINGLEHOP      UNIQUE_MATCH
# 3   EBGP_SINGLEHOP      UNIQUE_MATCH
# 4   EBGP_SINGLEHOP      UNIQUE_MATCH
# ..             ...               ...
# 59  EBGP_SINGLEHOP      UNIQUE_MATCH
# 60  EBGP_SINGLEHOP      UNIQUE_MATCH
# 61  EBGP_SINGLEHOP      UNIQUE_MATCH
# 62  EBGP_SINGLEHOP      UNIQUE_MATCH
# 63  EBGP_SINGLEHOP      UNIQUE_MATCH
#
# [64 rows x 12 columns]

# %% [markdown]
# Both of the configured BGP peers on `as2dept1` are compatible. We know that since the `Configured_Status` is `UNIQUE_MATCH`. So now let's check if they are established.

# %%
# Check if the bgp Sessions on as2dept1 are ESTABLISHED
bgpSessStat = bfq.bgpSessionStatus().answer().frame()
bgpSessStat
# Out:
#              Node      VRF Local_AS Local_Interface  Local_IP Remote_AS  \
# 0   aggregation-0  default        9            None  10.0.0.1         1
# 1   aggregation-0  default        9            None  10.0.1.1         2
# 2   aggregation-0  default        9            None  10.0.2.0        13
# 3   aggregation-0  default        9            None  10.0.2.2        13
# 4   aggregation-1  default        9            None  10.0.0.3         1
# ..            ...      ...      ...             ...       ...       ...
# 59         edge-5  default        6            None  10.2.1.2        11
# 60         edge-6  default        7            None  10.3.0.0        12
# 61         edge-6  default        7            None  10.3.0.2        12
# 62         edge-7  default        8            None  10.3.1.0        12
# 63         edge-7  default        8            None  10.3.1.2        12
#
#       Remote_Node Remote_Interface Remote_IP  Address_Families  \
# 0          edge-0             None  10.0.0.0  ['IPV4_UNICAST']
# 1          edge-1             None  10.0.1.0  ['IPV4_UNICAST']
# 2          core-0             None  10.0.2.1  ['IPV4_UNICAST']
# 3          core-1             None  10.0.2.3  ['IPV4_UNICAST']
# 4          edge-0             None  10.0.0.2  ['IPV4_UNICAST']
# ..            ...              ...       ...               ...
# 59  aggregation-5             None  10.2.1.3  ['IPV4_UNICAST']
# 60  aggregation-6             None  10.3.0.1  ['IPV4_UNICAST']
# 61  aggregation-7             None  10.3.0.3  ['IPV4_UNICAST']
# 62  aggregation-6             None  10.3.1.1  ['IPV4_UNICAST']
# 63  aggregation-7             None  10.3.1.3  ['IPV4_UNICAST']
#
#       Session_Type Established_Status
# 0   EBGP_SINGLEHOP        ESTABLISHED
# 1   EBGP_SINGLEHOP        ESTABLISHED
# 2   EBGP_SINGLEHOP        ESTABLISHED
# 3   EBGP_SINGLEHOP        ESTABLISHED
# 4   EBGP_SINGLEHOP        ESTABLISHED
# ..             ...                ...
# 59  EBGP_SINGLEHOP        ESTABLISHED
# 60  EBGP_SINGLEHOP        ESTABLISHED
# 61  EBGP_SINGLEHOP        ESTABLISHED
# 62  EBGP_SINGLEHOP        ESTABLISHED
# 63  EBGP_SINGLEHOP        ESTABLISHED
#
# [64 rows x 12 columns]

# %% [markdown]
# Both sessions are established. Let's see if there are any configured BGP sessions, on any other device in the network, that are not established

# %%
# Find any BGP sessions in the network that are NOT ESTABLISHED
bgpSessStat = bfq.bgpSessionStatus().answer().frame()
bgpSessStat[bgpSessStat['Established_Status'] == 'ESTABLISHED']
# Out:
#              Node      VRF Local_AS Local_Interface  Local_IP Remote_AS  \
# 0   aggregation-0  default        9            None  10.0.0.1         1
# 1   aggregation-0  default        9            None  10.0.1.1         2
# 2   aggregation-0  default        9            None  10.0.2.0        13
# 3   aggregation-0  default        9            None  10.0.2.2        13
# 4   aggregation-1  default        9            None  10.0.0.3         1
# 5   aggregation-1  default        9            None  10.0.1.3         2
# 6   aggregation-1  default        9            None  10.0.3.0        13
# 7   aggregation-1  default        9            None  10.0.3.2        13
# 8   aggregation-2  default       10            None  10.1.0.1         3
# 9   aggregation-2  default       10            None  10.1.1.1         4
# 12  aggregation-3  default       10            None  10.1.0.3         3
# 13  aggregation-3  default       10            None  10.1.1.3         4
# 16  aggregation-4  default       11            None  10.2.0.1         5
# 17  aggregation-4  default       11            None  10.2.1.1         6
# 20  aggregation-5  default       11            None  10.2.0.3         5
# 21  aggregation-5  default       11            None  10.2.1.3         6
# 24  aggregation-6  default       12            None  10.3.0.1         7
# 25  aggregation-6  default       12            None  10.3.1.1         8
# 26  aggregation-6  default       12            None  10.3.2.0        13
# 27  aggregation-6  default       12            None  10.3.2.2        13
# 28  aggregation-7  default       12            None  10.3.0.3         7
# 29  aggregation-7  default       12            None  10.3.1.3         8
# 30  aggregation-7  default       12            None  10.3.3.0        13
# 31  aggregation-7  default       12            None  10.3.3.2        13
# 32         core-0  default       13            None  10.0.2.1         9
# 35         core-0  default       13            None  10.3.2.1        12
# 36         core-1  default       13            None  10.0.2.3         9
# 39         core-1  default       13            None  10.3.2.3        12
# 40         core-2  default       13            None  10.0.3.1         9
# 43         core-2  default       13            None  10.3.3.1        12
# 44         core-3  default       13            None  10.0.3.3         9
# 47         core-3  default       13            None  10.3.3.3        12
# 48         edge-0  default        1            None  10.0.0.0         9
# 49         edge-0  default        1            None  10.0.0.2         9
# 50         edge-1  default        2            None  10.0.1.0         9
# 51         edge-1  default        2            None  10.0.1.2         9
# 52         edge-2  default        3            None  10.1.0.0        10
# 53         edge-2  default        3            None  10.1.0.2        10
# 54         edge-3  default        4            None  10.1.1.0        10
# 55         edge-3  default        4            None  10.1.1.2        10
# 56         edge-4  default        5            None  10.2.0.0        11
# 57         edge-4  default        5            None  10.2.0.2        11
# 58         edge-5  default        6            None  10.2.1.0        11
# 59         edge-5  default        6            None  10.2.1.2        11
# 60         edge-6  default        7            None  10.3.0.0        12
# 61         edge-6  default        7            None  10.3.0.2        12
# 62         edge-7  default        8            None  10.3.1.0        12
# 63         edge-7  default        8            None  10.3.1.2        12
#
#       Remote_Node Remote_Interface Remote_IP  Address_Families  \
# 0          edge-0             None  10.0.0.0  ['IPV4_UNICAST']
# 1          edge-1             None  10.0.1.0  ['IPV4_UNICAST']
# 2          core-0             None  10.0.2.1  ['IPV4_UNICAST']
# 3          core-1             None  10.0.2.3  ['IPV4_UNICAST']
# 4          edge-0             None  10.0.0.2  ['IPV4_UNICAST']
# 5          edge-1             None  10.0.1.2  ['IPV4_UNICAST']
# 6          core-2             None  10.0.3.1  ['IPV4_UNICAST']
# 7          core-3             None  10.0.3.3  ['IPV4_UNICAST']
# 8          edge-2             None  10.1.0.0  ['IPV4_UNICAST']
# 9          edge-3             None  10.1.1.0  ['IPV4_UNICAST']
# 12         edge-2             None  10.1.0.2  ['IPV4_UNICAST']
# 13         edge-3             None  10.1.1.2  ['IPV4_UNICAST']
# 16         edge-4             None  10.2.0.0  ['IPV4_UNICAST']
# 17         edge-5             None  10.2.1.0  ['IPV4_UNICAST']
# 20         edge-4             None  10.2.0.2  ['IPV4_UNICAST']
# 21         edge-5             None  10.2.1.2  ['IPV4_UNICAST']
# 24         edge-6             None  10.3.0.0  ['IPV4_UNICAST']
# 25         edge-7             None  10.3.1.0  ['IPV4_UNICAST']
# 26         core-0             None  10.3.2.1  ['IPV4_UNICAST']
# 27         core-1             None  10.3.2.3  ['IPV4_UNICAST']
# 28         edge-6             None  10.3.0.2  ['IPV4_UNICAST']
# 29         edge-7             None  10.3.1.2  ['IPV4_UNICAST']
# 30         core-2             None  10.3.3.1  ['IPV4_UNICAST']
# 31         core-3             None  10.3.3.3  ['IPV4_UNICAST']
# 32  aggregation-0             None  10.0.2.0  ['IPV4_UNICAST']
# 35  aggregation-6             None  10.3.2.0  ['IPV4_UNICAST']
# 36  aggregation-0             None  10.0.2.2  ['IPV4_UNICAST']
# 39  aggregation-6             None  10.3.2.2  ['IPV4_UNICAST']
# 40  aggregation-1             None  10.0.3.0  ['IPV4_UNICAST']
# 43  aggregation-7             None  10.3.3.0  ['IPV4_UNICAST']
# 44  aggregation-1             None  10.0.3.2  ['IPV4_UNICAST']
# 47  aggregation-7             None  10.3.3.2  ['IPV4_UNICAST']
# 48  aggregation-0             None  10.0.0.1  ['IPV4_UNICAST']
# 49  aggregation-1             None  10.0.0.3  ['IPV4_UNICAST']
# 50  aggregation-0             None  10.0.1.1  ['IPV4_UNICAST']
# 51  aggregation-1             None  10.0.1.3  ['IPV4_UNICAST']
# 52  aggregation-2             None  10.1.0.1  ['IPV4_UNICAST']
# 53  aggregation-3             None  10.1.0.3  ['IPV4_UNICAST']
# 54  aggregation-2             None  10.1.1.1  ['IPV4_UNICAST']
# 55  aggregation-3             None  10.1.1.3  ['IPV4_UNICAST']
# 56  aggregation-4             None  10.2.0.1  ['IPV4_UNICAST']
# 57  aggregation-5             None  10.2.0.3  ['IPV4_UNICAST']
# 58  aggregation-4             None  10.2.1.1  ['IPV4_UNICAST']
# 59  aggregation-5             None  10.2.1.3  ['IPV4_UNICAST']
# 60  aggregation-6             None  10.3.0.1  ['IPV4_UNICAST']
# 61  aggregation-7             None  10.3.0.3  ['IPV4_UNICAST']
# 62  aggregation-6             None  10.3.1.1  ['IPV4_UNICAST']
# 63  aggregation-7             None  10.3.1.3  ['IPV4_UNICAST']
#
#       Session_Type Established_Status
# 0   EBGP_SINGLEHOP        ESTABLISHED
# 1   EBGP_SINGLEHOP        ESTABLISHED
# 2   EBGP_SINGLEHOP        ESTABLISHED
# 3   EBGP_SINGLEHOP        ESTABLISHED
# 4   EBGP_SINGLEHOP        ESTABLISHED
# 5   EBGP_SINGLEHOP        ESTABLISHED
# 6   EBGP_SINGLEHOP        ESTABLISHED
# 7   EBGP_SINGLEHOP        ESTABLISHED
# 8   EBGP_SINGLEHOP        ESTABLISHED
# 9   EBGP_SINGLEHOP        ESTABLISHED
# 12  EBGP_SINGLEHOP        ESTABLISHED
# 13  EBGP_SINGLEHOP        ESTABLISHED
# 16  EBGP_SINGLEHOP        ESTABLISHED
# 17  EBGP_SINGLEHOP        ESTABLISHED
# 20  EBGP_SINGLEHOP        ESTABLISHED
# 21  EBGP_SINGLEHOP        ESTABLISHED
# 24  EBGP_SINGLEHOP        ESTABLISHED
# 25  EBGP_SINGLEHOP        ESTABLISHED
# 26  EBGP_SINGLEHOP        ESTABLISHED
# 27  EBGP_SINGLEHOP        ESTABLISHED
# 28  EBGP_SINGLEHOP        ESTABLISHED
# 29  EBGP_SINGLEHOP        ESTABLISHED
# 30  EBGP_SINGLEHOP        ESTABLISHED
# 31  EBGP_SINGLEHOP        ESTABLISHED
# 32  EBGP_SINGLEHOP        ESTABLISHED
# 35  EBGP_SINGLEHOP        ESTABLISHED
# 36  EBGP_SINGLEHOP        ESTABLISHED
# 39  EBGP_SINGLEHOP        ESTABLISHED
# 40  EBGP_SINGLEHOP        ESTABLISHED
# 43  EBGP_SINGLEHOP        ESTABLISHED
# 44  EBGP_SINGLEHOP        ESTABLISHED
# 47  EBGP_SINGLEHOP        ESTABLISHED
# 48  EBGP_SINGLEHOP        ESTABLISHED
# 49  EBGP_SINGLEHOP        ESTABLISHED
# 50  EBGP_SINGLEHOP        ESTABLISHED
# 51  EBGP_SINGLEHOP        ESTABLISHED
# 52  EBGP_SINGLEHOP        ESTABLISHED
# 53  EBGP_SINGLEHOP        ESTABLISHED
# 54  EBGP_SINGLEHOP        ESTABLISHED
# 55  EBGP_SINGLEHOP        ESTABLISHED
# 56  EBGP_SINGLEHOP        ESTABLISHED
# 57  EBGP_SINGLEHOP        ESTABLISHED
# 58  EBGP_SINGLEHOP        ESTABLISHED
# 59  EBGP_SINGLEHOP        ESTABLISHED
# 60  EBGP_SINGLEHOP        ESTABLISHED
# 61  EBGP_SINGLEHOP        ESTABLISHED
# 62  EBGP_SINGLEHOP        ESTABLISHED
# 63  EBGP_SINGLEHOP        ESTABLISHED

# %% [markdown]
# Looking at the `Established_Status` column we see that there are a lot of sessions that are configured, but not established. Let's dig into these issues.
#
# First, let's find all of the sessions that are not compatibly configured. For that we are looking for sessions which are not either a `UNIQUE_MATCH` or `DYNAMIC_MATCH`. The latter is for `dynamic` peers (these are peers configured to use a `listen-range`).

# %% [markdown]
# ### Debug NOT_COMPATIBLE sessions

# %%
# Find BGP sessions that are not compatibly configured - i.e Batfish does not identify them as being a UNIQUE_MATCH or a DYNAMIC_MATCH
bgpSessCompat = bfq.bgpSessionCompatibility().answer().frame()
bgpSessCompat[~bgpSessCompat['Configured_Status'].isin(["UNIQUE_MATCH", "DYNAMIC_MATCH"])]
# Out:
#              Node      VRF Local_AS Local_Interface  Local_IP Remote_AS  \
# 10  aggregation-2  default       10            None  10.1.2.0        13
# 11  aggregation-2  default       10            None  10.1.2.2        13
# 14  aggregation-3  default       10            None  10.1.3.0        13
# 15  aggregation-3  default       10            None  10.1.3.2        13
# 18  aggregation-4  default       11            None  10.2.2.0        13
# 19  aggregation-4  default       11            None  10.2.2.2        13
# 22  aggregation-5  default       11            None  10.2.3.0        13
# 23  aggregation-5  default       11            None  10.2.3.2        13
# 33         core-0  default       13            None      None        10
# 34         core-0  default       13            None      None        11
# 37         core-1  default       13            None      None        10
# 38         core-1  default       13            None      None        11
# 41         core-2  default       13            None      None        10
# 42         core-2  default       13            None      None        11
# 45         core-3  default       13            None      None        10
# 46         core-3  default       13            None      None        11
#
#    Remote_Node Remote_Interface Remote_IP Address_Families    Session_Type  \
# 10        None             None  10.1.2.1               []  EBGP_SINGLEHOP
# 11        None             None  10.1.2.3               []  EBGP_SINGLEHOP
# 14        None             None  10.1.3.1               []  EBGP_SINGLEHOP
# 15        None             None  10.1.3.3               []  EBGP_SINGLEHOP
# 18        None             None  10.2.2.1               []  EBGP_SINGLEHOP
# 19        None             None  10.2.2.3               []  EBGP_SINGLEHOP
# 22        None             None  10.2.3.1               []  EBGP_SINGLEHOP
# 23        None             None  10.2.3.3               []  EBGP_SINGLEHOP
# 33        None             None  10.1.2.0               []  EBGP_SINGLEHOP
# 34        None             None  10.2.2.0               []  EBGP_SINGLEHOP
# 37        None             None  10.1.2.2               []  EBGP_SINGLEHOP
# 38        None             None  10.2.2.2               []  EBGP_SINGLEHOP
# 41        None             None  10.1.3.0               []  EBGP_SINGLEHOP
# 42        None             None  10.2.3.0               []  EBGP_SINGLEHOP
# 45        None             None  10.1.3.2               []  EBGP_SINGLEHOP
# 46        None             None  10.2.3.2               []  EBGP_SINGLEHOP
#
#    Configured_Status
# 10    UNKNOWN_REMOTE
# 11    UNKNOWN_REMOTE
# 14    UNKNOWN_REMOTE
# 15    UNKNOWN_REMOTE
# 18    UNKNOWN_REMOTE
# 19    UNKNOWN_REMOTE
# 22    UNKNOWN_REMOTE
# 23    UNKNOWN_REMOTE
# 33       NO_LOCAL_IP
# 34       NO_LOCAL_IP
# 37       NO_LOCAL_IP
# 38       NO_LOCAL_IP
# 41       NO_LOCAL_IP
# 42       NO_LOCAL_IP
# 45       NO_LOCAL_IP
# 46       NO_LOCAL_IP

# %% [markdown]
# We see 4 entries in this table even though we only saw 3 BGP session with thes status NOT_COMPATIBLE. This means that despite not having a `Configured_Status` of `UNIQUE_MATCH` or `DYNAMIC_MATCH` one of these sessions was indeed established. This typically occurs if the mis-configuration is such that the session can ONLY be established when initiated from one side, but not the other. The likely candidate in this output is the `as2border2` session to `2.1.2.2` that has status of `LOCAL_IP_UNKNOWN_STATICALLY`.

# %% [markdown]
# ### Debug UNKNOWN_REMOTE peer on as1border2

# %% [markdown]
# Batfish deems the BGP peer `10.14.22.4` is not compatible because it cannot find a device in the snapshot that has that IP address configured on any interface. That is why the status is `UNKNOWN_REMOTE`.
# This will occur in  most networks, since you will not have the configurations of the devices for your external peers (ISPs, content partners, etc...). We can easily verify this by checking the output of `bfq.ipOwners`

# %%
# check if there is a node in the network that has the `10.14.22.4` on an interface
ipOwn = bfq.ipOwners().answer().frame()
ipOwn[ipOwn['IP']=='10.14.22.4']
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Interface, IP, Mask, Active]
# Index: []

# %% [markdown]
# ### Debug LOCAL_IP_UNKNOWN_STATICALLY on as2border2

# %% [markdown]
# Now, let's dig into the sessions that are `LOCAL_IP_UNKNOWN_STATICALLY`.
#
# An iBGP session will have the status `LOCAL_IP_UNKNOWN_STATICALLY` if you are missing the `update-source` command.
#
# So, in this case, it is likely that the issue is that `as2border2` is missing the `update-source` command for the BGP session. This is needed for iBGP sessions to ensure the peers pick the correct IP address to use when trying to establish the TCP session. We can find out the target remote node by looking at the `bfq.ipOwners` output

# %%
#find the device(s) that own these ip addresses
ipOwn[ipOwn['IP'].isin(['2.1.2.2'])]
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Interface, IP, Mask, Active]
# Index: []

# %% [markdown]
# So this session is supposed to be between `as2border2` and `as2core2`. Let's see if this session is established.

# %%
# check if either direction of the session can be established
bgpSessStat[((bgpSessStat['Local_IP']=='2.1.1.2') & (bgpSessStat['Remote_IP']=='2.1.2.2')) | ((bgpSessStat['Local_IP']=='2.1.2.2') & (bgpSessStat['Remote_IP']=='2.1.1.2'))]
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Local_AS, Local_Interface, Local_IP, Remote_AS, Remote_Node, Remote_Interface, Remote_IP, Address_Families, Session_Type, Established_Status]
# Index: []

# %% [markdown]
# This confirms that our theory. We are missing the `update-source` command on `as2border2` which prevents it from initiating the BGP session. But since `as2core2` is properly configured, the session is established.

# %% [markdown]
# ### Debug NO_LOCAL_IP on as1border1

# %%
# Identify the BGP sessions on as1border1 that are not compatible with Configured_Status of NO_LOCAL_IP
bgpSessCompat[(bgpSessCompat['Configured_Status'] == 'NO_LOCAL_IP') & (bgpSessCompat['Node']=='as1border1')]
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Local_AS, Local_Interface, Local_IP, Remote_AS, Remote_Node, Remote_Interface, Remote_IP, Address_Families, Session_Type, Configured_Status]
# Index: []

# %% [markdown]
# For an `EBGP_SINGLEHOP` session to have `CONFIGURED_STATUS` of `NO_LOCAL_IP` this typically means that no interface exists on the box which is in the same subnet as the BGP peer's IP address. This can easily be checked by looking at the IP addresses configued on `as1border1`.

# %%
# Identify the IP addresses that are owned by as1border1
ipOwn[ipOwn['Node']=='as1border1']
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Interface, IP, Mask, Active]
# Index: []

# %% [markdown]
# As you can see there are no interfaces with addresses that would be in the same subnet as `3.2.2.2` and `5.6.7.8`. There could be many explanations for this:
#
# 1) BGP peers were configured before the physical connection to neighboring routers was up.
#
# 2) The user simply configured the wrong BGP peer address.
#
# 3) The interfaces used to exist but were decommissioned, but the BGP config was not cleaned up at the same time.
#
# 4) The session is meant to be be an eBGP multi-hop session, but the user didn't add the `ebgp multihop` configuration option and specify an `update-source`.

# %% [markdown]
# Batfish determines the Local_IP for each BGP session, either based on explicit configuration with `updates-source foo` (or equivalent non-IOS command) for iBGP sessions or eBGP multi-hop sessions,
# or by determining the interface the router will use to send packets towards the BGP peer. The latter method requires the route to the peer to be known.
#
# So, if there is no route to the configured peer, or the configured peer does not exist in the snapshot, you will see this status. We can check the output of `bfq.routes` and `bfq.ipOwners` questions to dig into this

# %%
# Find owner of IP addresses for the incompatible BGP sessions on as1border`
bad_bgp_peer = ['3.2.2.2', '5.6.7.8']
ipOwn[ipOwn['IP'].isin(bad_bgp_peer)]
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Interface, IP, Mask, Active]
# Index: []

# %% [markdown]
# So we can see that `5.6.7.8` does not exist in the network. This either means there is a mis-configuration, or the device is just not expected to be in the snapshot.

# %% [markdown]
# Now let's dig into the peer `3.2.2.2`, which we know is the Loopback interface on `as3border2`

# %%
# retrieve the routing table entry for as3border2 loopback0 - 3.2.2.2/32 on as1border1
routes = bfq.routes(network='3.2.2.2/32').answer().frame()
routes[routes['Node']=='as1border1']
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Network, Next_Hop, Next_Hop_IP, Next_Hop_Interface, Protocol, Metric, Admin_Distance, Tag]
# Index: []

# %% [markdown]
# The specific /32 is not present on `as1border1`. What about other routers?

# %%
# retrieve the routing table entry for as3border2 loopback0 - 3.2.2.2/32 on ALL routers in the network
routes
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Network, Next_Hop, Next_Hop_IP, Next_Hop_Interface, Protocol, Metric, Admin_Distance, Tag]
# Index: []

# %% [markdown]
# We can see that this route does not leave `as3`, which is why `as1border1` is unable to established the configured BGP session.
# This session should have been configured as an eBGP multi-hop session with static routes pointing to the appropriate interface and next-hop

# %% [markdown]
# ### Debugging BGP sessions that are NOT_ESTABLISHED

# %% [markdown]
# We have root-caused the `NOT_COMPATIBLE` sessions, now let's dig into the ones that are `NOT_ESTABLISHED`.

# %%
# Find all BGP sessions in the network that were compatible but NOT_ESTABLISHED
bgpSessStat[bgpSessStat['Established_Status'] == 'ESTABLISHED']
# Out:
#              Node      VRF Local_AS Local_Interface  Local_IP Remote_AS  \
# 0   aggregation-0  default        9            None  10.0.0.1         1
# 1   aggregation-0  default        9            None  10.0.1.1         2
# 2   aggregation-0  default        9            None  10.0.2.0        13
# 3   aggregation-0  default        9            None  10.0.2.2        13
# 4   aggregation-1  default        9            None  10.0.0.3         1
# 5   aggregation-1  default        9            None  10.0.1.3         2
# 6   aggregation-1  default        9            None  10.0.3.0        13
# 7   aggregation-1  default        9            None  10.0.3.2        13
# 8   aggregation-2  default       10            None  10.1.0.1         3
# 9   aggregation-2  default       10            None  10.1.1.1         4
# 12  aggregation-3  default       10            None  10.1.0.3         3
# 13  aggregation-3  default       10            None  10.1.1.3         4
# 16  aggregation-4  default       11            None  10.2.0.1         5
# 17  aggregation-4  default       11            None  10.2.1.1         6
# 20  aggregation-5  default       11            None  10.2.0.3         5
# 21  aggregation-5  default       11            None  10.2.1.3         6
# 24  aggregation-6  default       12            None  10.3.0.1         7
# 25  aggregation-6  default       12            None  10.3.1.1         8
# 26  aggregation-6  default       12            None  10.3.2.0        13
# 27  aggregation-6  default       12            None  10.3.2.2        13
# 28  aggregation-7  default       12            None  10.3.0.3         7
# 29  aggregation-7  default       12            None  10.3.1.3         8
# 30  aggregation-7  default       12            None  10.3.3.0        13
# 31  aggregation-7  default       12            None  10.3.3.2        13
# 32         core-0  default       13            None  10.0.2.1         9
# 35         core-0  default       13            None  10.3.2.1        12
# 36         core-1  default       13            None  10.0.2.3         9
# 39         core-1  default       13            None  10.3.2.3        12
# 40         core-2  default       13            None  10.0.3.1         9
# 43         core-2  default       13            None  10.3.3.1        12
# 44         core-3  default       13            None  10.0.3.3         9
# 47         core-3  default       13            None  10.3.3.3        12
# 48         edge-0  default        1            None  10.0.0.0         9
# 49         edge-0  default        1            None  10.0.0.2         9
# 50         edge-1  default        2            None  10.0.1.0         9
# 51         edge-1  default        2            None  10.0.1.2         9
# 52         edge-2  default        3            None  10.1.0.0        10
# 53         edge-2  default        3            None  10.1.0.2        10
# 54         edge-3  default        4            None  10.1.1.0        10
# 55         edge-3  default        4            None  10.1.1.2        10
# 56         edge-4  default        5            None  10.2.0.0        11
# 57         edge-4  default        5            None  10.2.0.2        11
# 58         edge-5  default        6            None  10.2.1.0        11
# 59         edge-5  default        6            None  10.2.1.2        11
# 60         edge-6  default        7            None  10.3.0.0        12
# 61         edge-6  default        7            None  10.3.0.2        12
# 62         edge-7  default        8            None  10.3.1.0        12
# 63         edge-7  default        8            None  10.3.1.2        12
#
#       Remote_Node Remote_Interface Remote_IP  Address_Families  \
# 0          edge-0             None  10.0.0.0  ['IPV4_UNICAST']
# 1          edge-1             None  10.0.1.0  ['IPV4_UNICAST']
# 2          core-0             None  10.0.2.1  ['IPV4_UNICAST']
# 3          core-1             None  10.0.2.3  ['IPV4_UNICAST']
# 4          edge-0             None  10.0.0.2  ['IPV4_UNICAST']
# 5          edge-1             None  10.0.1.2  ['IPV4_UNICAST']
# 6          core-2             None  10.0.3.1  ['IPV4_UNICAST']
# 7          core-3             None  10.0.3.3  ['IPV4_UNICAST']
# 8          edge-2             None  10.1.0.0  ['IPV4_UNICAST']
# 9          edge-3             None  10.1.1.0  ['IPV4_UNICAST']
# 12         edge-2             None  10.1.0.2  ['IPV4_UNICAST']
# 13         edge-3             None  10.1.1.2  ['IPV4_UNICAST']
# 16         edge-4             None  10.2.0.0  ['IPV4_UNICAST']
# 17         edge-5             None  10.2.1.0  ['IPV4_UNICAST']
# 20         edge-4             None  10.2.0.2  ['IPV4_UNICAST']
# 21         edge-5             None  10.2.1.2  ['IPV4_UNICAST']
# 24         edge-6             None  10.3.0.0  ['IPV4_UNICAST']
# 25         edge-7             None  10.3.1.0  ['IPV4_UNICAST']
# 26         core-0             None  10.3.2.1  ['IPV4_UNICAST']
# 27         core-1             None  10.3.2.3  ['IPV4_UNICAST']
# 28         edge-6             None  10.3.0.2  ['IPV4_UNICAST']
# 29         edge-7             None  10.3.1.2  ['IPV4_UNICAST']
# 30         core-2             None  10.3.3.1  ['IPV4_UNICAST']
# 31         core-3             None  10.3.3.3  ['IPV4_UNICAST']
# 32  aggregation-0             None  10.0.2.0  ['IPV4_UNICAST']
# 35  aggregation-6             None  10.3.2.0  ['IPV4_UNICAST']
# 36  aggregation-0             None  10.0.2.2  ['IPV4_UNICAST']
# 39  aggregation-6             None  10.3.2.2  ['IPV4_UNICAST']
# 40  aggregation-1             None  10.0.3.0  ['IPV4_UNICAST']
# 43  aggregation-7             None  10.3.3.0  ['IPV4_UNICAST']
# 44  aggregation-1             None  10.0.3.2  ['IPV4_UNICAST']
# 47  aggregation-7             None  10.3.3.2  ['IPV4_UNICAST']
# 48  aggregation-0             None  10.0.0.1  ['IPV4_UNICAST']
# 49  aggregation-1             None  10.0.0.3  ['IPV4_UNICAST']
# 50  aggregation-0             None  10.0.1.1  ['IPV4_UNICAST']
# 51  aggregation-1             None  10.0.1.3  ['IPV4_UNICAST']
# 52  aggregation-2             None  10.1.0.1  ['IPV4_UNICAST']
# 53  aggregation-3             None  10.1.0.3  ['IPV4_UNICAST']
# 54  aggregation-2             None  10.1.1.1  ['IPV4_UNICAST']
# 55  aggregation-3             None  10.1.1.3  ['IPV4_UNICAST']
# 56  aggregation-4             None  10.2.0.1  ['IPV4_UNICAST']
# 57  aggregation-5             None  10.2.0.3  ['IPV4_UNICAST']
# 58  aggregation-4             None  10.2.1.1  ['IPV4_UNICAST']
# 59  aggregation-5             None  10.2.1.3  ['IPV4_UNICAST']
# 60  aggregation-6             None  10.3.0.1  ['IPV4_UNICAST']
# 61  aggregation-7             None  10.3.0.3  ['IPV4_UNICAST']
# 62  aggregation-6             None  10.3.1.1  ['IPV4_UNICAST']
# 63  aggregation-7             None  10.3.1.3  ['IPV4_UNICAST']
#
#       Session_Type Established_Status
# 0   EBGP_SINGLEHOP        ESTABLISHED
# 1   EBGP_SINGLEHOP        ESTABLISHED
# 2   EBGP_SINGLEHOP        ESTABLISHED
# 3   EBGP_SINGLEHOP        ESTABLISHED
# 4   EBGP_SINGLEHOP        ESTABLISHED
# 5   EBGP_SINGLEHOP        ESTABLISHED
# 6   EBGP_SINGLEHOP        ESTABLISHED
# 7   EBGP_SINGLEHOP        ESTABLISHED
# 8   EBGP_SINGLEHOP        ESTABLISHED
# 9   EBGP_SINGLEHOP        ESTABLISHED
# 12  EBGP_SINGLEHOP        ESTABLISHED
# 13  EBGP_SINGLEHOP        ESTABLISHED
# 16  EBGP_SINGLEHOP        ESTABLISHED
# 17  EBGP_SINGLEHOP        ESTABLISHED
# 20  EBGP_SINGLEHOP        ESTABLISHED
# 21  EBGP_SINGLEHOP        ESTABLISHED
# 24  EBGP_SINGLEHOP        ESTABLISHED
# 25  EBGP_SINGLEHOP        ESTABLISHED
# 26  EBGP_SINGLEHOP        ESTABLISHED
# 27  EBGP_SINGLEHOP        ESTABLISHED
# 28  EBGP_SINGLEHOP        ESTABLISHED
# 29  EBGP_SINGLEHOP        ESTABLISHED
# 30  EBGP_SINGLEHOP        ESTABLISHED
# 31  EBGP_SINGLEHOP        ESTABLISHED
# 32  EBGP_SINGLEHOP        ESTABLISHED
# 35  EBGP_SINGLEHOP        ESTABLISHED
# 36  EBGP_SINGLEHOP        ESTABLISHED
# 39  EBGP_SINGLEHOP        ESTABLISHED
# 40  EBGP_SINGLEHOP        ESTABLISHED
# 43  EBGP_SINGLEHOP        ESTABLISHED
# 44  EBGP_SINGLEHOP        ESTABLISHED
# 47  EBGP_SINGLEHOP        ESTABLISHED
# 48  EBGP_SINGLEHOP        ESTABLISHED
# 49  EBGP_SINGLEHOP        ESTABLISHED
# 50  EBGP_SINGLEHOP        ESTABLISHED
# 51  EBGP_SINGLEHOP        ESTABLISHED
# 52  EBGP_SINGLEHOP        ESTABLISHED
# 53  EBGP_SINGLEHOP        ESTABLISHED
# 54  EBGP_SINGLEHOP        ESTABLISHED
# 55  EBGP_SINGLEHOP        ESTABLISHED
# 56  EBGP_SINGLEHOP        ESTABLISHED
# 57  EBGP_SINGLEHOP        ESTABLISHED
# 58  EBGP_SINGLEHOP        ESTABLISHED
# 59  EBGP_SINGLEHOP        ESTABLISHED
# 60  EBGP_SINGLEHOP        ESTABLISHED
# 61  EBGP_SINGLEHOP        ESTABLISHED
# 62  EBGP_SINGLEHOP        ESTABLISHED
# 63  EBGP_SINGLEHOP        ESTABLISHED

# %% [markdown]
# The  reasons for a session that is compatiable (`UNIQUE_MATCH` or `DYNAMIC_MATCH`) to not get established would be 1) missing routes or 2) some ACL in the path blocking traffic. Let's check the routing tables on `as2core1`

# %%
# retrieve routing table for as2core1 and check the route to the BGP peer 2.1.1.1 - as2border1
routes = bfq.routes(nodes='a0').answer().frame()
routes
# Out:
# Empty DataFrame
# Columns: [Node, VRF, Network, Next_Hop, Next_Hop_IP, Next_Hop_Interface, Protocol, Metric, Admin_Distance, Tag]
# Index: []

# %%
# retrieve routing table for as2core1 and check the route to the BGP peer 2.1.1.1 - as2border1
routes = bfq.routes(nodes='aggregation-2').answer().frame()
routes
# Out:
#              Node      VRF       Network Next_Hop     Next_Hop_IP  \
# 0   aggregation-2  default   10.1.2.0/32     None  AUTO/NONE(-1l)
# 1   aggregation-2  default   10.1.2.2/32     None  AUTO/NONE(-1l)
# 2   aggregation-2  default   70.0.5.0/24   edge-2        10.1.0.0
# 3   aggregation-2  default   10.1.0.1/32     None  AUTO/NONE(-1l)
# 4   aggregation-2  default   70.0.6.0/24   edge-3        10.1.1.0
# 5   aggregation-2  default   10.1.0.0/31     None  AUTO/NONE(-1l)
# 6   aggregation-2  default   10.1.1.0/31     None  AUTO/NONE(-1l)
# 7   aggregation-2  default   10.1.2.0/31     None  AUTO/NONE(-1l)
# 8   aggregation-2  default  70.0.18.0/32     None  AUTO/NONE(-1l)
# 9   aggregation-2  default   10.1.1.1/32     None  AUTO/NONE(-1l)
# 10  aggregation-2  default   10.1.2.2/31     None  AUTO/NONE(-1l)
# 11  aggregation-2  default   70.0.4.0/24   edge-2        10.1.0.0
# 12  aggregation-2  default   70.0.7.0/24   edge-3        10.1.1.0
#
#    Next_Hop_Interface   Protocol Metric Admin_Distance   Tag
# 0             Serial2      local      0              0  None
# 1             Serial3      local      0              0  None
# 2             dynamic        bgp      0             20  None
# 3             Serial0      local      0              0  None
# 4             dynamic        bgp      0             20  None
# 5             Serial0  connected      0              0  None
# 6             Serial1  connected      0              0  None
# 7             Serial2  connected      0              0  None
# 8           Loopback0  connected      0              0  None
# 9             Serial1      local      0              0  None
# 10            Serial3  connected      0              0  None
# 11            dynamic        bgp      0             20  None
# 12            dynamic        bgp      0             20  None

# %% [markdown]
# As we can see `as2core1` has a route to the configured neighbor `2.1.1.1`. What about the other routers?

# %%
# retrieve routing table for as2border1 to check if it has a route to as2core1 loopback0 - 2.1.2.1/32
routes=bfq.routes(nodes='core-0').answer().frame()
routes
# Out:
#       Node      VRF       Network       Next_Hop     Next_Hop_IP  \
# 0   core-0  default  70.0.14.0/24  aggregation-6        10.3.2.0
# 1   core-0  default   70.0.0.0/24  aggregation-0        10.0.2.0
# 2   core-0  default   10.3.2.1/32           None  AUTO/NONE(-1l)
# 3   core-0  default   10.0.2.0/31           None  AUTO/NONE(-1l)
# 4   core-0  default   10.3.2.0/31           None  AUTO/NONE(-1l)
# 5   core-0  default  70.0.15.0/24  aggregation-6        10.3.2.0
# 6   core-0  default  70.0.13.0/24  aggregation-6        10.3.2.0
# 7   core-0  default   70.0.3.0/24  aggregation-0        10.0.2.0
# 8   core-0  default  70.0.24.0/32           None  AUTO/NONE(-1l)
# 9   core-0  default  70.0.12.0/24  aggregation-6        10.3.2.0
# 10  core-0  default   10.0.2.1/32           None  AUTO/NONE(-1l)
# 11  core-0  default   70.0.1.0/24  aggregation-0        10.0.2.0
# 12  core-0  default   70.0.2.0/24  aggregation-0        10.0.2.0
#
#    Next_Hop_Interface   Protocol Metric Admin_Distance   Tag
# 0             dynamic        bgp      0             20  None
# 1             dynamic        bgp      0             20  None
# 2             Serial1      local      0              0  None
# 3             Serial0  connected      0              0  None
# 4             Serial1  connected      0              0  None
# 5             dynamic        bgp      0             20  None
# 6             dynamic        bgp      0             20  None
# 7             dynamic        bgp      0             20  None
# 8           Loopback0  connected      0              0  None
# 9             dynamic        bgp      0             20  None
# 10            Serial0      local      0              0  None
# 11            dynamic        bgp      0             20  None
# 12            dynamic        bgp      0             20  None

# %% [markdown]
# `as2border1` does not have a route to the loopback address `2.1.2.1` of `as2core1`. Let's also check `as2border2`.

# %%
# retrieve routing table for as2border2 to check if it has a route to as2core1 loopback0 - 2.1.2.1/32
routes=bfq.routes(nodes='aggregation-1').answer().frame()
routes
# Out:
#              Node      VRF       Network Next_Hop     Next_Hop_IP  \
# 0   aggregation-1  default  70.0.13.0/24   core-2        10.0.3.1
# 1   aggregation-1  default  70.0.17.0/32     None  AUTO/NONE(-1l)
# 2   aggregation-1  default   70.0.0.0/24   edge-0        10.0.0.2
# 3   aggregation-1  default   70.0.3.0/24   edge-1        10.0.1.2
# 4   aggregation-1  default   70.0.1.0/24   edge-0        10.0.0.2
# 5   aggregation-1  default  70.0.14.0/24   core-2        10.0.3.1
# 6   aggregation-1  default   10.0.0.2/31     None  AUTO/NONE(-1l)
# 7   aggregation-1  default   10.0.3.0/31     None  AUTO/NONE(-1l)
# 8   aggregation-1  default   10.0.3.2/31     None  AUTO/NONE(-1l)
# 9   aggregation-1  default   10.0.3.0/32     None  AUTO/NONE(-1l)
# 10  aggregation-1  default   10.0.0.3/32     None  AUTO/NONE(-1l)
# 11  aggregation-1  default   10.0.1.2/31     None  AUTO/NONE(-1l)
# 12  aggregation-1  default   10.0.3.2/32     None  AUTO/NONE(-1l)
# 13  aggregation-1  default   10.0.1.3/32     None  AUTO/NONE(-1l)
# 14  aggregation-1  default  70.0.12.0/24   core-2        10.0.3.1
# 15  aggregation-1  default  70.0.15.0/24   core-2        10.0.3.1
# 16  aggregation-1  default   70.0.2.0/24   edge-1        10.0.1.2
#
#    Next_Hop_Interface   Protocol Metric Admin_Distance   Tag
# 0             dynamic        bgp      0             20  None
# 1           Loopback0  connected      0              0  None
# 2             dynamic        bgp      0             20  None
# 3             dynamic        bgp      0             20  None
# 4             dynamic        bgp      0             20  None
# 5             dynamic        bgp      0             20  None
# 6             Serial0  connected      0              0  None
# 7             Serial2  connected      0              0  None
# 8             Serial3  connected      0              0  None
# 9             Serial2      local      0              0  None
# 10            Serial0      local      0              0  None
# 11            Serial1  connected      0              0  None
# 12            Serial3      local      0              0  None
# 13            Serial1      local      0              0  None
# 14            dynamic        bgp      0             20  None
# 15            dynamic        bgp      0             20  None
# 16            dynamic        bgp      0             20  None

# %% [markdown]
# Neither border router has a route to the loopback of `as2core1`. Since the loopback is supposed to be distributed via OSPF, next step is to look at the OSPF configuration on `as2core1`

# %% [markdown]
# From the snippet of the configuration of `as2core1`, we can see that the Loopback address isn't part of the OSPF process:
# ```
# interface Loopback0
#  ip address 2.1.2.1 255.255.255.255
#
# router ospf 1
#  router-id 2.1.2.1
#  !network 2.0.0.0 0.255.255.255 area 1
#  network 2.12.0.0 0.0.255.255 area 1
#  network 2.23.0.0 0.0.255.255 area 1
#  ```
#
#  This explains why the BGP session wasn't established.

# %% [markdown]
# With that we have root-caused all of the BGP sessions that were `NOT_ESTABLISHED` or `NOT_COMPATIBLE`.

# %% [markdown]
# ### Summary

# %% [markdown]
# Batfish allows you to easily retrieve information about BGP configuration of all devices and peers, as well as status of each peer. With Batfish you can ensure that no change is pushed to the network that would cause a BGP session to not come up.

# %% [markdown]
# We hope you found this notebook useful and informative. Future notebooks will dive into more advanced topics like validating routing policy. Stay tuned!

# %% [markdown]
# Want to learn more? Come find us on [Slack](https://join.slack.com/t/batfish-org/shared_invite/enQtMzA0Nzg2OTAzNzQ1LTUxOTJlY2YyNTVlNGQ3MTJkOTIwZT     U2YjY3YzRjZWFiYzE4ODE5ODZiNjA4NGI5NTJhZmU2ZTllOTMwZDhjMzA) and [GitHub](https://github.com/batfish/batfish)
